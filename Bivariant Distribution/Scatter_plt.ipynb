# %% [markdown]
# # Basic Scatter Plot (Matplotlib)

# %% [markdown]
# ## Basic Scatter Plot (Matplotlib)

# %%
! pip install --force-reinstall --no-deps matplotlib==3.10.7
# Out:
# Collecting matplotlib==3.10.7
#   Using cached matplotlib-3.10.7-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Using cached matplotlib-3.10.7-cp310-cp310-win_amd64.whl (8.1 MB)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.7
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\nil\appdata\local\programs\python\python310\lib\site-packages)
# error: uninstall-no-record-file
#
# × Cannot uninstall matplotlib 3.10.7
# ╰─> The package's contents are unknown: no RECORD file was found for matplotlib.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps matplotlib==3.10.7

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#
# File c:\Users\NIL\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:52
#      50 from cycler import cycler
#      51 import matplotlib
# ---> 52 import matplotlib.colorbar
#      53 import matplotlib.image
#      54 from matplotlib import _api
#
# File c:\Users\NIL\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File c:\Users\NIL\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\collections.py:20
#      17 import numpy as np
#      19 import matplotlib as mpl
# ---> 20 from . import (_api, _path, artist, cbook, cm, colors as mcolors, _docstring,
#      21                hatch as mhatch, lines as mlines, path as mpath, transforms)
#      22 from ._enums import JoinStyle, CapStyle
#      25 # "color" is excluded; it is a compound setter, and its docstring differs
#      26 # in LineCollection.
#
# File c:\Users\NIL\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\lines.py:14
#      12 import matplotlib as mpl
#      13 from . import _api, cbook, colors as mcolors, _docstring
# ---> 14 from .artist import Artist, allow_rasterization
#      15 from .cbook import (
#      16     _to_unmasked_float_array, ls_mapper, ls_mapper_r, STEP_LOOKUP_MAP)
#      17 from .markers import MarkerStyle
#
# ModuleNotFoundError: No module named 'matplotlib.artist'

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['x'], df['y'])
plt.title("Basic Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 plt.figure(figsize=(8,6))
#       2 plt.scatter(df['x'], df['y'])
#       3 plt.title("Basic Scatter Plot")
#
# NameError: name 'plt' is not defined
