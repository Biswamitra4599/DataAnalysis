# %% [markdown]
# ## ACF Plot (Using Statsmodels) — Recommended

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# -------------------------
# Sample Time-Series Data
# -------------------------
np.random.seed(42)
N = 200
data = np.cumsum(np.random.randn(N))  # random walk

df = pd.DataFrame({"value": data})

# -------------------------
# ACF Plot
# -------------------------
plt.figure(figsize=(10, 5))
plot_acf(df['value'], lags=40)
plt.title("Autocorrelation Plot (ACF)", fontsize=16)
plt.show()

# %% [markdown]
# ## Quick ACF Plot (Using Pandas)
#
# This is a simpler version:

# %%
from pandas.plotting import autocorrelation_plot

plt.figure(figsize=(10, 5))
autocorrelation_plot(df['value'])
plt.title("Autocorrelation Plot")
plt.show()

# %% [markdown]
# ## Using Your Own Data (List of values)
#
# If you have:

# %%
values = [12, 15, 14, 19, 22]

# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

values = [12, 15, 14, 19, 22, 21, 30, 29]  # your values
df = pd.Series(values)

plot_acf(df, lags=len(values)//2)
plt.show()
